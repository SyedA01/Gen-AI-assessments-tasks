# %% [raw]
# # NUMPY
#
# # NumPy is the core library for numerical computing in Python.
#
# # It provides a fast, memory efficient array object called ndarray along with a large collection of operations for creating arrays, reshaping them, performing mathematical computations, and applying linear algebra.

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.26.4

# %% [raw]
# # Arrays can be created in several ways. They can be built directly from Python lists, filled with a constant value, generated as identity matrices, or produced as evenly spaced sequences using arange and linspace

# %%
a = np.array([1, 2, 3]) # 1d array
b = np.array([[1, 2, 3], [4, 5, 6]]) # 2d array
#-------------------------------------------------

z = np.zeros((2, 3))
ones = np.ones((3, 3))

# ------------------------------------------------
identity = np.eye(3)
ar = np.arange(0, 10, 2)
lin = np.linspace(0, 1, 6)
# ------------------------------------------------

#print(a)
#print(b)
#print(z)
#print(ones)
print(identity)
print(ar)
print(lin)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# [0 2 4 6 8]
# [0.  0.2 0.4 0.6 0.8 1. ]

# %% [raw]
# # Every array carries attributes that describe it, such as its shape, the number of dimensions, the total number of elements, and the data type of its elements.

# %%
# Numpy Attributes
#-----------------
print(b)
print(b.shape) # returns number of ROWS & COLS
print(b.ndim)  # returns number of DIMENSION
print(b.size)  # returns the product of rows & cols
print(b.dtype) # returns the exact datatype of values stored in numpy arrays
# Out:
# [[1 2 3]
#  [4 5 6]]
# (2, 3)
# 2
# 6
# int32

# %% [raw]
# # Individual elements or slices of an array can be accessed using indexing and slicing

# %%
print(b)
#print(b[0, 1])
#print(b[:, 2])  # if slicinng starts with : followed by a num then it returns entire num column values 
#print(b[1, :]) # if slicing starts with num ffolloweed by : then it returns entire num row values
print(b[0:2, 0:2])
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[1 2]
#  [4 5]]

# %% [raw]
# # Arrays can be reshaped into different dimensions as long as the total number of elements stays the same.
# # Flatten and ravel convert a multi dimensional array back into a single dimension.

# %%
#print(ar)  # [0 2 4 6 8]  # (1,5)
#reshaped = ar.reshape(5, 1)
#print(reshaped)
#print(ar)
#print(b)
#flat = b.flatten() # flatten converts any array into 1d array temporarily
#print(flat)
print(b)

raveled = b.ravel()
print(raveled)
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [1 2 3 4 5 6]
# [[1 2 3]
#  [4 5 6]]

# %% [raw]
# # Arithmetic operations in NumPy are applied element wise. This includes addition, subtraction, multiplication, division, and exponentiation, all of which work directly on whole arrays without writing explicit loops.

# %%
x = np.array([1, 2, 3]) # 1d
y = np.array([4, 5, 6]) # 1d

print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x ** 2)
# Out:
# [5 7 9]
# [-3 -3 -3]
# [ 4 10 18]
# [0.25 0.4  0.5 ]
# [1 4 9]

# %% [raw]
# # Broadcasting allows NumPy to perform operations on arrays of different shapes by automatically expanding the smaller array so the shapes become compatible.

# %%
matrix = np.array([[1, 2, 3], [4, 5, 6]])
vector = np.array([10, 20, 30])

print(matrix + vector)
# Out:
# [[11 22 33]
#  [14 25 36]]

# %% [raw]
# # Aggregation functions reduce an array down to summary statistics such as the sum, mean, median, standard deviation, variance, minimum, and maximum, either across the whole array or along a chosen axis

# %%
#print(matrix.sum())
#print(matrix.mean())
#print(np.median(matrix))
#print(matrix.std())
#print(matrix.var())
#print(matrix.min())
#print(matrix.max())
print(matrix)
#print(matrix.sum(axis=0))
#print(matrix.sum(axis=1))
# Out:
# [[1 2 3]
#  [4 5 6]]
# [ 6 15]

# %% [raw]
# # NumPy also supports linear algebra operations including the dot product, matrix multiplication, transposition, matrix inversion, and the determinant of a matrix.

# %%
m1 = np.array([[1, 2], [3, 4]])
m2 = np.array([[5, 6], [7, 8]])

print(np.dot(m1, m2)) # row * column - split multiplication using dot matrix * 
print(m1 @ m2) # here @ represents DOT MATRIX MULTIPLICATION
#print(m1)
#print(m1.T)
# Out:
# [[19 22]
#  [43 50]]
# [[19 22]
#  [43 50]]

# %% [raw]
# # Random numbers can be generated using the random module, which can produce uniformly distributed values, random integers, and values drawn from a normal distribution. Setting a seed makes the results reproducible

# %%
#np.random.seed(42)

#print(np.random.rand(2, 3)) # finger print authentication 
#print(np.random.randint(100, 210, size=(2, 3))) # otp 
print(np.random.randn(2, 3))
# Out:
# [[ 2.11050284  0.52801052 -0.03321567]
#  [-0.69371863 -0.5178737  -0.26649174]]

# %% [raw]
# # Multiple arrays can be combined using stacking and concatenation, and a single array can be divided into smaller parts using split.

# %%
v1 = np.array([1, 2, 3])
v2 = np.array([4, 5, 6])

#print(np.vstack((v1, v2)))
#print(np.hstack((v1, v2)))
#print(np.concatenate((v1, v2)))
print(np.split(np.arange(9), 3))
# Out:
# [array([0, 1, 2]), array([3, 4, 5]), array([6, 7, 8])]

# %% [raw]
# # Arrays can be sorted, and the positions of elements that satisfy a condition can be located using sort, argsort, and where.

# %%
unsorted = np.array([3, 1, 4, 1, 5, 9, 2, 6])

#print(np.sort(unsorted))
#print(np.argsort(unsorted)) # used in  gen ai along with SLM
#print(np.where(unsorted > 3)) # conditional sorting
# Out:
# (array([2, 4, 5, 7], dtype=int64),)

# %% [raw]
# # Boolean indexing makes it possible to filter an array based on a condition, returning only the elements that meet the criteria.

# %%
data = np.array([10, 15, 20, 25, 30])
mask = data > 18

print(mask)
print(data[mask])
# Out:
# [False False  True  True  True]
# [20 25 30]

# %% [raw]
# # Finally, arrays can be saved to disk and loaded back later using the save and load functions, which store the data in the NumPy binary format.

# %%
np.save('array_data.npy', data)
loaded = np.load('array_data.npy')

print(loaded)
